# %% [markdown]
# ## Summary of Kaggle IPL Dataset:
#
# This Kaggle dataset contains information about cricket players who participated in the Indian Premier League (IPL). The dataset includes the following columns:
#
# Position (POS): This column ranks cricket players based on specific metrics such as runs, average, or strike rate. A lower value indicates a higher rank, providing insight into a player's performance within the league.
#
# Player: This column contains the names of the cricket players who participated in the IPL.
#
# Team: The "Team" column displays the name of the IPL team for which each player represented during the IPL season.
#
# Matches (Mat): Represents the number of matches in which a player participated throughout the IPL season, indicating their overall involvement in the league.
#
# Innings (Inns): Denotes the number of innings in which a player batted during the IPL season, reflecting how frequently a player had the opportunity to bat.
#
# Not Outs (NO): Indicates the number of times a player remained not out after completing their innings, showcasing their ability to stay at the crease until the end of an inning.
#
# Runs: Displays the total number of runs a player scored across all their innings during the IPL season, highlighting their overall run-scoring contribution.
#
# Highest Score (HS): Represents a player's highest individual score in a single inning during the IPL season, showcasing their ability to excel and set a benchmark for their performance.
#
# Batting Average (Avg): Calculates a player's batting average, which is the total runs scored divided by the number of times the player has been dismissed. This metric provides a measure of the player's consistency and ability to convert starts into substantial innings.
#
# Balls Faced (BF): Indicates the total number of balls faced by a player across all their innings in the IPL season, offering insights into a player's ability to handle deliveries effectively.
#
# Strike Rate (SR): Reflects the player's strike rate, which is the number of runs scored per 100 balls faced, providing an overview of their ability to score quickly.
#
# Centuries (100): Shows the number of centuries (100 or more runs in an inning) scored by each player.
#
# Fifties (50): Indicates the number of half-centuries (50 or more runs in an inning) scored by each player.
#
# Fours (4s): Represents the number of fours hit by each player during the IPL season.
#
# Sixes (6s): Displays the number of sixes hit by each player during the IPL season.
#
# Additionally, the dataset includes some data preprocessing and visualization code snippets, such as:
#
# Extracting the top 10 highest IPL run-scorers.
#
# Finding the player who played the highest number of matches.
#
# Visualizing the top 10 players with the most "not out" innings.
#
# Identifying players with the most runs from boundaries (4s and 6s).
#
# Visualizing the top 10 players with the most sixes.
#
# Visualizing the top 10 players with the highest strike rates.
#
# Separating players who scored their highest runs when they were not out and those who were out.
#
# Identifying players with the most centuries and half-centuries.
#
# Visualizing the top 10 players with the highest batting averages.
#
# The dataset provides valuable insights into the performance of cricket players in the IPL, allowing for in-depth analysis and visualization of various player statistics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('All-Time-Best-Batsman.csv')

# %%
df.head()
# Out:
#    POS          Player  Team  Mat  Inns  NO  Runs    HS    Avg    BF      SR  \
# 0    1     Virat Kohli   RCB  237   229  34  7263   113  37.25  5586  130.02
# 1    2  Shikhar Dhawan  PKBS  217   216  29  6617  106*  35.39  5203  127.18
# 2    3    David Warner    DC  176   176  22  6397   126  41.54  4572  139.92
# 3    4    Rohit Sharma    MI  243   238  28  6211  109*  29.58  4776  130.05
# 4    5    Suresh Raina   CSK  205   200  30  5528  100*  32.52  4042  136.76
#
#    100  50   4s   6s
# 0    7  50  643  234
# 1    2  50  750  148
# 2    4  60  646  226
# 3    1  42  554  257
# 4    1  39  506  203

# %%
df.shape
# Out:
# (135, 15)

# %%
df.isnull().sum()
# Out:
# POS       0
# Player    0
# Team      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POS     135 non-null    int64
#  1   Player  135 non-null    object
#  2   Team    135 non-null    object
#  3   Mat     135 non-null    int64
#  4   Inns    135 non-null    int64
#  5   NO      135 non-null    int64
#  6   Runs    135 non-null    int64
#  7   HS      135 non-null    object
#  8   Avg     135 non-null    float64
#  9   BF      135 non-null    int64
#  10  SR      135 non-null    float64
#  11  100     135 non-null    int64
#  12  50      135 non-null    int64
#  13  4s      135 non-null    int64
#  14  6s      135 non-null    int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 15.9+ KB

# %%
#extracting top 10 highest ipl run scrorer
top10=df.sort_values(by='Runs',ascending=False).head(10)

# %%
import matplotlib.pyplot as plt
import seaborn as sns  # Import seaborn for better aesthetics

# Set a custom color palette
sns.set_palette("husl")

# Create a figure and axis with specified dimensions
plt.figure(figsize=(12, 8))

# Plot the bar chart
plt.bar(top10["Player"], top10["Runs"], color=sns.color_palette("husl"))
plt.xlabel("Players Name")
plt.ylabel("Run Scored")
plt.title("Top 10 Runs Scorers in IPL")

# Rotate player names for better readability
plt.xticks(rotation=45, ha="right")

# Add data labels above the bars
for x, y in enumerate(top10["Runs"]):
    plt.text(x, y + 100, str(y), ha="center", va="bottom")

# Add grid lines for better visualization
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Customize the appearance of the plot
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)

# Show the plot
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    POS          Player  Team  Mat  Inns  NO  Runs   HS    Avg    BF      SR  \
# 0    1     Virat Kohli   RCB  237   229  34  7263  113  37.25  5586  130.02
# 1    2  Shikhar Dhawan  PKBS  217   216  29  6617  106  35.39  5203  127.18
# 2    3    David Warner    DC  176   176  22  6397  126  41.54  4572  139.92
# 3    4    Rohit Sharma    MI  243   238  28  6211  109  29.58  4776  130.05
# 4    5    Suresh Raina   CSK  205   200  30  5528  100  32.52  4042  136.76
#
#    100  50   4s   6s  6_and_4_runs  HS_NT
# 0    7  50  643  234          3976      0
# 1    2  50  750  148          3888      1
# 2    4  60  646  226          3940      0
# 3    1  42  554  257          3758      1
# 4    1  39  506  203          3242      1

# %%
# Trying to find out the player who have played highest matches
top10=df.sort_values(by='Mat',ascending=False).head(10)

# %%
#plotting bar diagram of top 10 highest ipl run scorer
plt.figure(figsize=(18, 11))
plt.bar(top10["Player"], top10["Mat"],color='blue')
plt.xlabel("Players Name")
plt.ylabel("Run Scored")
plt.title("Top 10 Player who have have played maximum matches")
plt.show()

# %%
#plotting bar diagram of top 10 who remained not out for a maximum matches
top10=df.sort_values(by='NO',ascending=False).head(10)

# Set the figure size for the plot
plt.figure(figsize=(12, 8))

# Create a bar chart to visualize the top 10 players with the most not outs
plt.bar(top10["Player"], top10["NO"], color='skyblue')

# Add labels to the X and Y axes
plt.xlabel("Player Names")
plt.ylabel("Number of Times Not Out")

# Set the title of the plot
plt.title("Top 10 Players with the Most of the Times are Not Outs")

# Display the plot
plt.xticks(rotation=45)  # Rotate player names for better readability
plt.tight_layout()  # Ensure proper spacing
plt.show()

# %%
df.head()
# Out:
#    POS          Player  Team  Mat  Inns  NO  Runs    HS    Avg    BF      SR  \
# 0    1     Virat Kohli   RCB  237   229  34  7263   113  37.25  5586  130.02
# 1    2  Shikhar Dhawan  PKBS  217   216  29  6617  106*  35.39  5203  127.18
# 2    3    David Warner    DC  176   176  22  6397   126  41.54  4572  139.92
# 3    4    Rohit Sharma    MI  243   238  28  6211  109*  29.58  4776  130.05
# 4    5    Suresh Raina   CSK  205   200  30  5528  100*  32.52  4042  136.76
#
#    100  50   4s   6s
# 0    7  50  643  234
# 1    2  50  750  148
# 2    4  60  646  226
# 3    1  42  554  257
# 4    1  39  506  203

# %%
# the palyer who have scored maxi runs from 4s and 6s alnone

# %%
df['6_and_4_runs'] = df['4s']*4 + df['6s']*6

# %%
df.head()
# Out:
#    POS          Player  Team  Mat  Inns  NO  Runs    HS    Avg    BF      SR  \
# 0    1     Virat Kohli   RCB  237   229  34  7263   113  37.25  5586  130.02
# 1    2  Shikhar Dhawan  PKBS  217   216  29  6617  106*  35.39  5203  127.18
# 2    3    David Warner    DC  176   176  22  6397   126  41.54  4572  139.92
# 3    4    Rohit Sharma    MI  243   238  28  6211  109*  29.58  4776  130.05
# 4    5    Suresh Raina   CSK  205   200  30  5528  100*  32.52  4042  136.76
#
#    100  50   4s   6s  6_and_4_runs
# 0    7  50  643  234          3976
# 1    2  50  750  148          3888
# 2    4  60  646  226          3940
# 3    1  42  554  257          3758
# 4    1  39  506  203          3242

# %%
top10=df.sort_values(by='6_and_4_runs',ascending=False).head(10)

colors = sns.color_palette("coolwarm", len(top10))

plt.figure(figsize=(12, 8))
plt.barh(top10["Player"], top10["6_and_4_runs"], color=colors)

plt.xlabel("4's and 6's Runs")
plt.ylabel("Player Names")

plt.title("Top 10 Players with the Most Runs from 4's and 6's")

plt.gca().invert_yaxis()  # Invert the Y-axis for better ranking visualization
plt.tight_layout()  # Ensure proper spacing
plt.show()

# %%
# Sort the DataFrame by '6s' (number of sixes) in descending order and select the top 10 players
top10 = df.sort_values(by='6s', ascending=False).head(10)

# Set a custom color palette for the plot
colors = sns.color_palette("viridis", len(top10))

# Set the figure size for the plot
plt.figure(figsize=(12, 8))

# Create a horizontal bar chart to visualize the top 10 players with the most sixes
plt.barh(top10["Player"], top10["6s"], color=colors)

# Add labels to the X and Y axes
plt.xlabel("Number of Sixes")
plt.ylabel("Player Names")

# Set the title of the plot
plt.title("Top 10 Players with the Most Sixes")

# Display the plot
plt.gca().invert_yaxis()  # Invert the Y-axis for better ranking visualization
plt.tight_layout()  # Ensure proper spacing
plt.show()

# %%
df.head()
# Out:
#    POS          Player  Team  Mat  Inns  NO  Runs    HS    Avg    BF      SR  \
# 0    1     Virat Kohli   RCB  237   229  34  7263   113  37.25  5586  130.02
# 1    2  Shikhar Dhawan  PKBS  217   216  29  6617  106*  35.39  5203  127.18
# 2    3    David Warner    DC  176   176  22  6397   126  41.54  4572  139.92
# 3    4    Rohit Sharma    MI  243   238  28  6211  109*  29.58  4776  130.05
# 4    5    Suresh Raina   CSK  205   200  30  5528  100*  32.52  4042  136.76
#
#    100  50   4s   6s  6_and_4_runs
# 0    7  50  643  234          3976
# 1    2  50  750  148          3888
# 2    4  60  646  226          3940
# 3    1  42  554  257          3758
# 4    1  39  506  203          3242

# %%
# Sort the DataFrame by 'SR' (strike rate) in descending order and select the top 10 players
top10 = df.sort_values(by='SR', ascending=False).head(10)

# Set a custom color palette with a gradient for the plot
colors = sns.color_palette("coolwarm", n_colors=len(top10))

# Set the figure size for the plot
plt.figure(figsize=(12, 8))

# Create a horizontal bar chart to visualize the top 10 players with a good strike rate
plt.barh(top10["Player"], top10["SR"], color=colors)

# Add labels to the X and Y axes
plt.xlabel("Strike Rate")
plt.ylabel("Player Names")

# Set the title of the plot
plt.title("Top 10 Players with the Best Strike Rates")

# Display the plot
plt.gca().invert_yaxis()  # Invert the Y-axis for better ranking visualization
plt.tight_layout()  # Ensure proper spacing
plt.show()

# %%
# TOP 5 player in IPL having high score as well as they are NOT OUT

# %%
df.head()
# Out:
#    POS          Player  Team  Mat  Inns  NO  Runs    HS    Avg    BF      SR  \
# 0    1     Virat Kohli   RCB  237   229  34  7263   113  37.25  5586  130.02
# 1    2  Shikhar Dhawan  PKBS  217   216  29  6617  106*  35.39  5203  127.18
# 2    3    David Warner    DC  176   176  22  6397   126  41.54  4572  139.92
# 3    4    Rohit Sharma    MI  243   238  28  6211  109*  29.58  4776  130.05
# 4    5    Suresh Raina   CSK  205   200  30  5528  100*  32.52  4042  136.76
#
#    100  50   4s   6s  6_and_4_runs
# 0    7  50  643  234          3976
# 1    2  50  750  148          3888
# 2    4  60  646  226          3940
# 3    1  42  554  257          3758
# 4    1  39  506  203          3242

# %%
def high_score(data):
    if data[-1]=='*':
        return 1
    else:
        return 0

# %% [markdown]
# Here 1 indicate Not Out
#
# and  0 indicated Out

# %%
df['HS_NT'] = df['HS'].apply(high_score)

# %%
df.head()
# Out:
#    POS          Player  Team  Mat  Inns  NO  Runs    HS    Avg    BF      SR  \
# 0    1     Virat Kohli   RCB  237   229  34  7263   113  37.25  5586  130.02
# 1    2  Shikhar Dhawan  PKBS  217   216  29  6617  106*  35.39  5203  127.18
# 2    3    David Warner    DC  176   176  22  6397   126  41.54  4572  139.92
# 3    4    Rohit Sharma    MI  243   238  28  6211  109*  29.58  4776  130.05
# 4    5    Suresh Raina   CSK  205   200  30  5528  100*  32.52  4042  136.76
#
#    100  50   4s   6s  6_and_4_runs  HS_NT
# 0    7  50  643  234          3976      0
# 1    2  50  750  148          3888      1
# 2    4  60  646  226          3940      0
# 3    1  42  554  257          3758      1
# 4    1  39  506  203          3242      1

# %%
#now we will replace the '*' in HS with ''[blank]

# %%
df['HS'] = df['HS'].str.replace('*','')
# Out:
# C:\Users\vinee\AppData\Local\Temp\ipykernel_12756\2847769331.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['HS'] = df['HS'].str.replace('*','')

# %%
# We will convert it to integer
df['HS'] = df['HS'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   POS           135 non-null    int64
#  1   Player        135 non-null    object
#  2   Team          135 non-null    object
#  3   Mat           135 non-null    int64
#  4   Inns          135 non-null    int64
#  5   NO            135 non-null    int64
#  6   Runs          135 non-null    int64
#  7   HS            135 non-null    int64
#  8   Avg           135 non-null    float64
#  9   BF            135 non-null    int64
#  10  SR            135 non-null    float64
#  11  100           135 non-null    int64
#  12  50            135 non-null    int64
#  13  4s            135 non-null    int64
#  14  6s            135 non-null    int64
#  15  6_and_4_runs  135 non-null    int64
#  16  HS_NT         135 non-null    int64
# dtypes: float64(2), int64(13), object(2)
# ...

# %%
df_hs = df[df['HS_NT']==1]

# %% [markdown]
# df_hs contains the player who  have high score but the things all these player are not out when scored the High Score

# %%
df_hs.head()
# Out:
#    POS          Player  Team  Mat  Inns  NO  Runs   HS    Avg    BF      SR  \
# 1    2  Shikhar Dhawan  PKBS  217   216  29  6617  106  35.39  5203  127.18
# 3    4    Rohit Sharma    MI  243   238  28  6211  109  29.58  4776  130.05
# 4    5    Suresh Raina   CSK  205   200  30  5528  100  32.52  4042  136.76
# 5    6  AB de Villiers   RCB  184   170  40  5162  133  39.70  3403  151.68
# 6    7        MS Dhoni   CSK  250   218  87  5082   84  38.79  3739  135.92
#
#    100  50   4s   6s  6_and_4_runs  HS_NT
# 1    2  50  750  148          3888      1
# 3    1  42  554  257          3758      1
# 4    1  39  506  203          3242      1
# 5    3  40  413  251          3158      1
# 6    0  24  349  239          2830      1

# %%
top10=df_hs.sort_values(by='HS',ascending=False).head(10)

plt.figure(figsize=(18, 11))
plt.bar(top10["Player"], top10["HS"],color='blue')
plt.xlabel("Players Name")
plt.ylabel("Run Scored")
plt.title("Top 10 Player who have Maximum high score when thet were not out")
# Out:
# Text(0.5, 1.0, 'Top 10 Player who have Maximum high score when thet were not out')

# %%
df_hs_o = df[df['HS_NT']!=1]

# %%
df_hs_o.head()
# Out:
#     POS          Player Team  Mat  Inns  NO  Runs   HS    Avg    BF      SR  \
# 0     1     Virat Kohli  RCB  237   229  34  7263  113  37.25  5586  130.02
# 2     3    David Warner   DC  176   176  22  6397  126  41.54  4572  139.92
# 8     9   Robin Uthappa  CSK  205   197  17  4952   88  27.51  3799  130.35
# 12   13  Gautam Gambhir   DC  154   152  16  4217   93  31.00  3404  123.88
# 14   15  Faf du Plessis  RCB  130   123  11  4133   96  36.90  3081  134.14
#
#     100  50   4s   6s  6_and_4_runs  HS_NT
# 0     7  50  643  234          3976      0
# 2     4  60  646  226          3940      0
# 8     0  27  481  182          3016      0
# 12    0  36  492   59          2322      0
# 14    0  33  374  145          2366      0

# %%
top10=df_hs_o.sort_values(by='HS',ascending=False).head(10)

plt.figure(figsize=(18, 11))
plt.bar(top10["Player"], top10["HS"],color='blue')
plt.xlabel("Players Name")
plt.ylabel("Run Scored")
plt.title("Top 10 Player who have Maximum high score when thet were out")
# Out:
# Text(0.5, 1.0, 'Top 10 Player who have Maximum high score when thet were not out')

# %%
# the palyer who maximum no of century's 
top10=df.sort_values(by='100',ascending=False).head(10)

plt.figure(figsize=(18, 11))
plt.bar(top10["Player"], top10["100"],color='blue')
plt.xlabel("Players Name")
plt.ylabel("4's and 6's")
plt.title("Top 10 Player who have maximum no of century's ")
plt.show()

# %%
# the palyer who maximum no of Fifties's 
top10=df.sort_values(by='50',ascending=False).head(10)

plt.figure(figsize=(18, 11))
plt.bar(top10["Player"], top10["50"],color='blue')
plt.xlabel("Players Name")
plt.ylabel("4's and 6's")
plt.title("Top 10 Player who have maximum no of century's ")
plt.show()

# %%
# the palyer having highest avg score 
top10=df.sort_values(by='Avg',ascending=False).head(10)

plt.figure(figsize=(18, 11))
plt.bar(top10["Player"], top10["Avg"],color='blue')
plt.xlabel("Players Name")
plt.ylabel("Avg Score")
plt.title("Top 10 Player who having highest avg score")
plt.show()

# %%
df.describe()
# Out:
#               POS         Mat        Inns          NO         Runs  \
# count  135.000000  135.000000  135.000000  135.000000   135.000000
# mean    68.000000   90.762963   81.096296   15.014815  1923.725926
# std     39.115214   57.184724   51.290346   13.869856  1468.473298
# min      1.000000   13.000000   13.000000    0.000000   503.000000
# 25%     34.500000   44.000000   39.500000    5.000000   826.500000
# 50%     68.000000   81.000000   71.000000   11.000000  1405.000000
# 75%    101.500000  119.500000  101.000000   21.000000  2655.500000
# max    135.000000  250.000000  238.000000   87.000000  7263.000000
#
#                HS         Avg           BF          SR         100  \
# count  135.000000  135.000000   135.000000  135.000000  135.000000
# mean    89.607407   28.540370  1453.318519  132.429407    0.614815
# std     23.555617    7.030537  1098.333063   12.339804    1.209324
# min     24.000000   11.710000   310.000000  106.810000    0.000000
# ...

# %% [markdown]
# ## Some observation -> Descrptive Analysis
#
# This datasets currently contains 135 data points so observation will be on that only
# - The means High Score is 89-90 Runs
# - The maximum match played by the player : 250
# - The minimum match played by the player : 90
# - The maximum match innings played by the player :  238
# - The minimum match innings palyed by the player : 13
# - The Maximum and Minimum times NO games : 87 and 0
# - This maximums and minimum high score : 175 and 24
# - The very good and very poor Strike Rate : 174 and 106
# - The Averge Strike Rate : 132.429407
